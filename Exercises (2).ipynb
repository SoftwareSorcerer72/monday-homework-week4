# %%
import re

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Write a function that takes in a tweet and returns a list of the hashtags in the tweet<br>
# Ex. 1<br>
# tweet = "Python is the best #Python #Programming #CodingTemple"<br>
# Expected Output: ["#Python", "#Programming", "#CodingTemple"]<br>
#
# Ex. 2<br>
# tweet = "I love my life! #blessed"<br>
# Expected Output: ["#bleesed"]<br>
#
# Ex. 3<br>
# tweet = "Bear Down"<br>
# Expected Output: []<br>

# %%
tweet1 = "Python is the best #Python #Programming #CodingTemple"
tweet2 = "I love my life! #blessed"
tweet3 = "Bear Down"

pattern = re.compile(r'#\w+')
sorted_tweets= pattern.findall(tweet1) + pattern.findall(tweet2) + pattern.findall(tweet3)
print(sorted_tweets)
# Out:
# ['#Python', '#Programming', '#CodingTemple', '#blessed']

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Develop a regular expression to validate a username. The username should start with a letter, followed by any combination of letters, numbers, underscores, and dots. It should be between 3 and 16 characters long<br>
# Ex. 1 <br>
# username = "CodingTemple123"<br>
# Expected Output: True<br>
#
# Ex. 2 <br>
# username = "1love"<br>
# Expected Output: False<br>
#
# Ex. 3 <br>
# username = "CT"<br>
# Expected Output: False<br>
#
# Ex. 4 <br>
# username = "This_is_a_username_that_I_would_like_to_use"<br>
# Expected Output: False<br>
#
# Ex. 5 <br>
# username = "brian_ct123"<br>
# Expected Output: True<br>

# %%
username1 = "CodingTemple123"
username2 = "1love"
username3 = "CT"
username4 = "This_is_a_username_that_I_would_like_to_use"
username5 = "brian_ct123"

username_list = [username1, username2, username3, username4, username5]
pattern = re.compile(r'^[a-zA-z]\w{3,16}$')
def username_validation():
    for names in username_list:
        if pattern.match(names):  
            print("Valid")
        else:
            print("Invalid")

run = username_validation()
# Out:
# Valid
# Invalid
# Invalid
# Invalid
# Valid

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Using the Python `open()` function, read in the `example.txt` file (attached in Google Classroom, make sure it is in the same folder as this notebook). Create a pattern that will find all of the dates in the text. Dates are in the format of YYYY-MM-DD. The pattern should have groups for year, month, and day. Using the `.finditer()` method, iterate over the dates and print in format of month/day/year<br>

# %% [markdown]
# Output:
# ```
# 05/15/1990
# 09/20/2015
# 12/03/1985
# 06/18/2010
# 11/30/2002
# 08/10/1978
# 04/25/1992
# 07/07/2019
# 02/12/1980
# 03/22/2005
# ```

# %%
with open('example.txt') as file:
    content = file.read()

# %%
pattern = re.compile(r'^\d{4})-\d{2})-\d{2})$')


for match in pattern.finditer(content):
    print(match)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pattern = re.compile(r'^\d{4})-\d{2})-\d{2})$')
#       4 for match in pattern.finditer(content):
#       5     print(match)
#
# File c:\Users\mikew\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:228, in compile(pattern, flags)
#     226 def compile(pattern, flags=0):
#     227     "Compile a regular expression pattern, returning a Pattern object."
# --> 228     return _compile(pattern, flags)
#
# File c:\Users\mikew\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File c:\Users\mikew\AppData\Local\Programs\Python\Python312\Lib\re\_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File c:\Users\mikew\AppData\Local\Programs\Python\Python312\Lib\re\_parser.py:984, in parse(str, flags, state)
#     982 if source.next is not None:
#     983     assert source.next == ")"
# --> 984     raise source.error("unbalanced parenthesis")
#     986 for g in p.state.grouprefpos:
#     987     if g >= p.state.groups:
#
# error: unbalanced parenthesis at position 6

# %%
pattern = re.compile(r'\d{4}-\d{2}-\d{2}')
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
